# %% [markdown]
# We will use the Industrial Optical Inspection Dataset.
# The blocks given below will help you copy and unzip the data from google drive.
#
# ---
#
#
# The dataset description can be found here : https://hci.iwr.uni-heidelberg.de/node/3616

# %% [markdown]
# # Google Colab
# Set the Runtime to GPU from the menu on the top left of this webpage
#
# Importing data to Google Colab

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Copy data to google colab from google drive and unzip
# This may take 1-2 minutes
# !cp gdrive/My\ Drive/Colab\ Notebooks/optical_data.zip .
# !unzip optical_data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: __MACOSX/data/Class1/Test/._0519.PNG
#   inflating: data/Class1/Test/0525.PNG
#   inflating: __MACOSX/data/Class1/Test/._0525.PNG
#   inflating: data/Class1/Test/0243.PNG
#   inflating: __MACOSX/data/Class1/Test/._0243.PNG
#   inflating: data/Class1/Test/0257.PNG
#   inflating: __MACOSX/data/Class1/Test/._0257.PNG
#   inflating: data/Class1/Test/0531.PNG
#   inflating: __MACOSX/data/Class1/Test/._0531.PNG
#   inflating: data/Class1/Test/0082.PNG
#   inflating: __MACOSX/data/Class1/Test/._0082.PNG
#   inflating: data/Class1/Test/0096.PNG
#   inflating: __MACOSX/data/Class1/Test/._0096.PNG
#   inflating: data/Class1/Test/0069.PNG
#   inflating: __MACOSX/data/Class1/Test/._0069.PNG
#   inflating: data/Class1/Test/0041.PNG
#   inflating: __MACOSX/data/Class1/Test/._0041.PNG
#   inflating: data/Class1/Test/0055.PNG
#   inflating: __MACOSX/data/Class1/Test/._0055.PNG
#   inflating: data/Class1/Test/0109.PNG
#   inflating: __MACOSX/data/Class1/Test/._0109.PNG
#   inflating: data/Class1/Test/0135.PNG
#   inflating: __MACOSX/data/Class1/Test/._0135.PNG
#   inflating: data/Class1/Test/0121.PNG
#   inflating: __MACOSX/data/Class1/Test/._0121.PNG
#   inflating: data/Class1/Test/0492.PNG
#   inflating: __MACOSX/data/Class1/Test/._0492.PNG
#   inflating: data/Class1/Test/0486.PNG
#   inflating: __MACOSX/data/Class1/Test/._0486.PNG
#   inflating: data/Class1/Test/0479.PNG
#   inflating: __MACOSX/data/Class1/Test/._0479.PNG
#   inflating: data/Class1/Test/0451.PNG
#   inflating: __MACOSX/data/Class1/Test/._0451.PNG
#   inflating: data/Class1/Test/0337.PNG
#   inflating: __MACOSX/data/Class1/Test/._0337.PNG
#   inflating: data/Class1/Test/0323.PNG
#   inflating: __MACOSX/data/Class1/Test/._0323.PNG
#   inflating: data/Class1/Test/0445.PNG
#   inflating: __MACOSX/data/Class1/Test/._0445.PNG
#   inflating: data/Class1/Test/0322.PNG
#   inflating: __MACOSX/data/Class1/Test/._0322.PNG
#   inflating: data/Class1/Test/0444.PNG
#   inflating: __MACOSX/data/Class1/Test/._0444.PNG
#   inflating: data/Class1/Test/0450.PNG
#   inflating: __MACOSX/data/Class1/Test/._0450.PNG
#   inflating: data/Class1/Test/0336.PNG
#   inflating: __MACOSX/data/Class1/Test/._0336.PNG
#   inflating: data/Class1/Test/0478.PNG
#   inflating: __MACOSX/data/Class1/Test/._0478.PNG
#   inflating: data/Class1/Test/0487.PNG
#   inflating: data/Class1/Train/0996.PNG
#   inflating: __MACOSX/data/Class1/Train/._0996.PNG
#   inflating: data/Class1/Train/0982.PNG
#   inflating: __MACOSX/data/Class1/Train/._0982.PNG
#   inflating: data/Class1/Train/0772.PNG
#   inflating: __MACOSX/data/Class1/Train/._0772.PNG
#   inflating: data/Class1/Train/0766.PNG
#   inflating: __MACOSX/data/Class1/Train/._0766.PNG
#   inflating: data/Class1/Train/0821.PNG
#   inflating: __MACOSX/data/Class1/Train/._0821.PNG
#   inflating: data/Class1/Train/0835.PNG
#   inflating: __MACOSX/data/Class1/Train/._0835.PNG
#   inflating: data/Class1/Train/0809.PNG
#   inflating: __MACOSX/data/Class1/Train/._0809.PNG
#   inflating: data/Class1/Train/Label/0871_label.PNG
#   inflating: data/Class1/Train/Label/0795_label.PNG
#   inflating: data/Class1/Train/Label/0937_label.PNG
#   inflating: data/Class1/Train/Label/1100_label.PNG
#   inflating: data/Class1/Train/Label/1046_label.PNG
#   inflating: data/Class1/Train/Label/0984_label.PNG
#   inflating: data/Class1/Train/Label/0660_label.PNG
#   inflating: data/Class1/Train/Label/0726_label.PNG
#   inflating: data/Class1/Train/Label/1028_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1028_label.PNG
#   inflating: data/Class1/Train/Label/0732_label.PNG
#   inflating: data/Class1/Train/Label/0674_label.PNG
#   inflating: data/Class1/Train/Label/0990_label.PNG
#   inflating: data/Class1/Train/Label/0959_label.PNG
#   inflating: data/Class1/Train/Label/1052_label.PNG
#   inflating: data/Class1/Train/Label/1114_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1114_label.PNG
#   inflating: data/Class1/Train/Label/0923_label.PNG
#   inflating: data/Class1/Train/Label/0781_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0781_label.PNG
#   inflating: data/Class1/Train/Label/0748_label.PNG
#   inflating: data/Class1/Train/Label/0865_label.PNG
#   inflating: data/Class1/Train/Label/1009_label.PNG
#   inflating: data/Class1/Train/Label/0713_label.PNG
#   inflating: data/Class1/Train/Label/0978_label.PNG
#   inflating: data/Class1/Train/Label/0655_label.PNG
#   inflating: data/Class1/Train/Label/1073_label.PNG
#   inflating: data/Class1/Train/Label/1135_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1135_label.PNG
#   inflating: data/Class1/Train/Label/0902_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0902_label.PNG
#   inflating: data/Class1/Train/Label/0596_label.PNG
#   inflating: data/Class1/Train/Label/0844_label.PNG
#   inflating: data/Class1/Train/Label/0769_label.PNG
#   inflating: data/Class1/Train/Label/0850_label.PNG
#   inflating: data/Class1/Train/Label/0899_label.PNG
#   inflating: data/Class1/Train/Label/0582_label.PNG
#   inflating: data/Class1/Train/Label/0916_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0916_label.PNG
#   inflating: data/Class1/Train/Label/1121_label.PNG
#   inflating: data/Class1/Train/Label/1067_label.PNG
#   inflating: data/Class1/Train/Label/0641_label.PNG
#   inflating: data/Class1/Train/Label/0688_label.PNG
#   inflating: data/Class1/Train/Label/0707_label.PNG
#   inflating: data/Class1/Train/Label/1082_label.PNG
#   inflating: data/Class1/Train/Label/0617_label.PNG
#   inflating: data/Class1/Train/Label/0751_label.PNG
#   inflating: data/Class1/Train/Label/0798_label.PNG
#   inflating: data/Class1/Train/Label/1031_label.PNG
#   inflating: data/Class1/Train/Label/0806_label.PNG
#   inflating: data/Class1/Train/Label/0940_label.PNG
#   inflating: data/Class1/Train/Label/0989_label.PNG
#   inflating: data/Class1/Train/Label/0954_label.PNG
#   inflating: data/Class1/Train/Label/0679_label.PNG
#   inflating: data/Class1/Train/Label/0812_label.PNG
#   inflating: data/Class1/Train/Label/1025_label.PNG
#   inflating: data/Class1/Train/Label/0868_label.PNG
#   inflating: data/Class1/Train/Label/0745_label.PNG
#   inflating: data/Class1/Train/Label/0603_label.PNG
#   inflating: data/Class1/Train/Label/1119_label.PNG
#   inflating: data/Class1/Train/Label/1096_label.PNG
#   inflating: data/Class1/Train/Label/0691_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0691_label.PNG
#   inflating: data/Class1/Train/Label/0658_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0658_label.PNG
#   inflating: data/Class1/Train/Label/0975_label.PNG
#   inflating: data/Class1/Train/Label/0833_label.PNG
#   inflating: data/Class1/Train/Label/1004_label.PNG
#   inflating: data/Class1/Train/Label/1142_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1142_label.PNG
#   inflating: data/Class1/Train/Label/0764_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0764_label.PNG
#   inflating: data/Class1/Train/Label/0880_label.PNG
#   inflating: data/Class1/Train/Label/0849_label.PNG
#   inflating: data/Class1/Train/Label/0622_label.PNG
#   inflating: data/Class1/Train/Label/1138_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1138_label.PNG
#   inflating: data/Class1/Train/Label/0636_label.PNG
#   inflating: data/Class1/Train/Label/0894_label.PNG
#   inflating: data/Class1/Train/Label/0770_label.PNG
#   inflating: data/Class1/Train/Label/1010_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1010_label.PNG
#   inflating: data/Class1/Train/Label/0827_label.PNG
#   inflating: data/Class1/Train/Label/0961_label.PNG
#   inflating: data/Class1/Train/Label/0685_label.PNG
#   inflating: data/Class1/Train/Label/1133_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1133_label.PNG
#   inflating: data/Class1/Train/Label/1075_label.PNG
#   inflating: data/Class1/Train/Label/0842_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0842_label.PNG
#   inflating: data/Class1/Train/Label/0590_label.PNG
#   inflating: data/Class1/Train/Label/0904_label.PNG
#   inflating: data/Class1/Train/Label/0629_label.PNG
#   inflating: data/Class1/Train/Label/1149_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1149_label.PNG
#   inflating: data/Class1/Train/Label/0653_label.PNG
#   inflating: data/Class1/Train/Label/0838_label.PNG
#   inflating: data/Class1/Train/Label/0715_label.PNG
#   inflating: data/Class1/Train/Label/0701_label.PNG
#   inflating: data/Class1/Train/Label/0647_label.PNG
#   inflating: data/Class1/Train/Label/.DS_Store
#   inflating: __MACOSX/data/Class1/Train/Label/._.DS_Store
#   inflating: data/Class1/Train/Label/0910_label.PNG
#   inflating: data/Class1/Train/Label/0584_label.PNG
#   inflating: data/Class1/Train/Label/0856_label.PNG
#   inflating: data/Class1/Train/Label/1061_label.PNG
#   inflating: data/Class1/Train/Label/1127_label.PNG
#   inflating: data/Class1/Train/Label/0720_label.PNG
#   inflating: data/Class1/Train/Label/0982_label.PNG
#   inflating: data/Class1/Train/Label/0666_label.PNG
#   inflating: data/Class1/Train/Label/0931_label.PNG
#   inflating: data/Class1/Train/Label/0877_label.PNG
#   inflating: data/Class1/Train/Label/0793_label.PNG
#   inflating: data/Class1/Train/Label/1040_label.PNG
#   inflating: data/Class1/Train/Label/1089_label.PNG
#   inflating: data/Class1/Train/Label/1106_label.PNG
#   inflating: data/Class1/Train/Label/1112_label.PNG
#   inflating: data/Class1/Train/Label/1054_label.PNG
#   inflating: data/Class1/Train/Label/0787_label.PNG
#   inflating: data/Class1/Train/Label/0578_label.PNG
#   inflating: data/Class1/Train/Label/0863_label.PNG
#   inflating: data/Class1/Train/Label/0608_label.PNG
#   inflating: data/Class1/Train/Label/0925_label.PNG
#   inflating: data/Class1/Train/Label/0672_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0672_label.PNG
#   inflating: data/Class1/Train/Label/0996_label.PNG
#   inflating: data/Class1/Train/Label/0734_label.PNG
#   inflating: data/Class1/Train/Label/0819_label.PNG
#   inflating: data/Class1/Train/Label/0624_label.PNG
#   inflating: data/Class1/Train/Label/0909_label.PNG
#   inflating: data/Class1/Train/Label/0762_label.PNG
#   inflating: data/Class1/Train/Label/0886_label.PNG
#   inflating: data/Class1/Train/Label/1078_label.PNG
#   inflating: data/Class1/Train/Label/0718_label.PNG
#   inflating: data/Class1/Train/Label/0835_label.PNG
#   inflating: data/Class1/Train/Label/0697_label.PNG
#   inflating: data/Class1/Train/Label/0973_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0973_label.PNG
#   inflating: data/Class1/Train/Label/1144_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1144_label.PNG
#   inflating: data/Class1/Train/Label/1002_label.PNG
#   inflating: data/Class1/Train/Label/1016_label.PNG
#   inflating: data/Class1/Train/Label/1150_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1150_label.PNG
#   inflating: data/Class1/Train/Label/0967_label.PNG
#   inflating: data/Class1/Train/Label/0683_label.PNG
#   inflating: data/Class1/Train/Label/0821_label.PNG
#   inflating: data/Class1/Train/Label/0892_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0892_label.PNG
#   inflating: data/Class1/Train/Label/0589_label.PNG
#   inflating: data/Class1/Train/Label/0776_label.PNG
#   inflating: data/Class1/Train/Label/0630_label.PNG
#   inflating: data/Class1/Train/Label/1037_label.PNG
#   inflating: data/Class1/Train/Label/0946_label.PNG
#   inflating: data/Class1/Train/Label/0800_label.PNG
#   inflating: data/Class1/Train/Label/1084_label.PNG
#   inflating: data/Class1/Train/Label/0757_label.PNG
#   inflating: data/Class1/Train/Label/0611_label.PNG
#   inflating: data/Class1/Train/Label/0928_label.PNG
#   inflating: data/Class1/Train/Label/0605_label.PNG
#   inflating: data/Class1/Train/Label/0743_label.PNG
#   inflating: data/Class1/Train/Label/1090_label.PNG
#   inflating: data/Class1/Train/Label/1059_label.PNG
#   inflating: data/Class1/Train/Label/0814_label.PNG
#   inflating: data/Class1/Train/Label/0739_label.PNG
#   inflating: data/Class1/Train/Label/0952_label.PNG
#   inflating: data/Class1/Train/Label/1023_label.PNG
#   inflating: data/Class1/Train/Label/1029_label.PNG
#   inflating: data/Class1/Train/Label/0675_label.PNG
#   inflating: data/Class1/Train/Label/0991_label.PNG
#   inflating: data/Class1/Train/Label/0958_label.PNG
#   inflating: data/Class1/Train/Label/0733_label.PNG
#   inflating: data/Class1/Train/Label/1115_label.PNG
#   inflating: data/Class1/Train/Label/1053_label.PNG
#   inflating: data/Class1/Train/Label/0780_label.PNG
#   inflating: data/Class1/Train/Label/0749_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0749_label.PNG
#   inflating: data/Class1/Train/Label/0864_label.PNG
#   inflating: data/Class1/Train/Label/0922_label.PNG
#   inflating: data/Class1/Train/Label/0936_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0936_label.PNG
#   inflating: data/Class1/Train/Label/0870_label.PNG
#   inflating: data/Class1/Train/Label/0794_label.PNG
#   inflating: data/Class1/Train/Label/1047_label.PNG
#   inflating: data/Class1/Train/Label/1101_label.PNG
#   inflating: data/Class1/Train/Label/0727_label.PNG
#   inflating: data/Class1/Train/Label/0985_label.PNG
#   inflating: data/Class1/Train/Label/0661_label.PNG
#   inflating: data/Class1/Train/Label/0917_label.PNG
#   inflating: data/Class1/Train/Label/0851_label.PNG
#   inflating: data/Class1/Train/Label/0898_label.PNG
#   inflating: data/Class1/Train/Label/0583_label.PNG
#   inflating: data/Class1/Train/Label/1066_label.PNG
#   inflating: data/Class1/Train/Label/1120_label.PNG
#   inflating: data/Class1/Train/Label/0706_label.PNG
#   inflating: data/Class1/Train/Label/0640_label.PNG
#   inflating: data/Class1/Train/Label/0689_label.PNG
#   inflating: data/Class1/Train/Label/1008_label.PNG
#   inflating: data/Class1/Train/Label/0979_label.PNG
#   inflating: data/Class1/Train/Label/0654_label.PNG
#   inflating: data/Class1/Train/Label/0712_label.PNG
#   inflating: data/Class1/Train/Label/1134_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1134_label.PNG
#   inflating: data/Class1/Train/Label/1072_label.PNG
#   inflating: data/Class1/Train/Label/0597_label.PNG
#   inflating: data/Class1/Train/Label/0845_label.PNG
#   inflating: data/Class1/Train/Label/0768_label.PNG
#   inflating: data/Class1/Train/Label/0903_label.PNG
#   inflating: data/Class1/Train/Label/0813_label.PNG
#   inflating: data/Class1/Train/Label/0955_label.PNG
#   inflating: data/Class1/Train/Label/0678_label.PNG
#   inflating: data/Class1/Train/Label/1024_label.PNG
#   inflating: data/Class1/Train/Label/0602_label.PNG
#   inflating: data/Class1/Train/Label/0869_label.PNG
#   inflating: data/Class1/Train/Label/0744_label.PNG
#   inflating: data/Class1/Train/Label/1097_label.PNG
#   inflating: data/Class1/Train/Label/1118_label.PNG
#   inflating: data/Class1/Train/Label/1083_label.PNG
#   inflating: data/Class1/Train/Label/0750_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0750_label.PNG
#   inflating: data/Class1/Train/Label/0799_label.PNG
#   inflating: data/Class1/Train/Label/0616_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0616_label.PNG
#   inflating: data/Class1/Train/Label/1030_label.PNG
#   inflating: data/Class1/Train/Label/0941_label.PNG
#   inflating: data/Class1/Train/Label/0988_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0988_label.PNG
#   inflating: data/Class1/Train/Label/0807_label.PNG
#   inflating: data/Class1/Train/Label/0895_label.PNG
#   inflating: data/Class1/Train/Label/0771_label.PNG
#   inflating: data/Class1/Train/Label/0637_label.PNG
#   inflating: data/Class1/Train/Label/1011_label.PNG
#   inflating: data/Class1/Train/Label/0960_label.PNG
#   inflating: data/Class1/Train/Label/0684_label.PNG
#   inflating: data/Class1/Train/Label/0826_label.PNG
#   inflating: data/Class1/Train/Label/0832_label.PNG
#   inflating: data/Class1/Train/Label/0690_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0690_label.PNG
#   inflating: data/Class1/Train/Label/0659_label.PNG
#   inflating: data/Class1/Train/Label/0974_label.PNG
#   inflating: data/Class1/Train/Label/1143_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1143_label.PNG
#   inflating: data/Class1/Train/Label/1005_label.PNG
#   inflating: data/Class1/Train/Label/0623_label.PNG
#   inflating: data/Class1/Train/Label/0765_label.PNG
#   inflating: data/Class1/Train/Label/0881_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0881_label.PNG
#   inflating: data/Class1/Train/Label/0848_label.PNG
#   inflating: data/Class1/Train/Label/1139_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1139_label.PNG
#   inflating: data/Class1/Train/Label/0646_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0646_label.PNG
#   inflating: data/Class1/Train/Label/0700_label.PNG
#   inflating: data/Class1/Train/Label/0585_label.PNG
#   inflating: data/Class1/Train/Label/0857_label.PNG
#   inflating: data/Class1/Train/Label/0911_label.PNG
#   inflating: data/Class1/Train/Label/1126_label.PNG
#   inflating: data/Class1/Train/Label/1060_label.PNG
#   inflating: data/Class1/Train/Label/1074_label.PNG
#   inflating: data/Class1/Train/Label/1132_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1132_label.PNG
#   inflating: data/Class1/Train/Label/0905_label.PNG
#   inflating: data/Class1/Train/Label/0628_label.PNG
#   inflating: data/Class1/Train/Label/0843_label.PNG
#   inflating: data/Class1/Train/Label/0591_label.PNG
#   inflating: data/Class1/Train/Label/1148_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1148_label.PNG
#   inflating: data/Class1/Train/Label/0839_label.PNG
#   inflating: data/Class1/Train/Label/0714_label.PNG
#   inflating: data/Class1/Train/Label/0652_label.PNG
#   inflating: data/Class1/Train/Label/1055_label.PNG
#   inflating: data/Class1/Train/Label/1113_label.PNG
#   inflating: data/Class1/Train/Label/0609_label.PNG
#   inflating: data/Class1/Train/Label/0924_label.PNG
#   inflating: data/Class1/Train/Label/0786_label.PNG
#   inflating: data/Class1/Train/Label/0579_label.PNG
#   inflating: data/Class1/Train/Label/0862_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0862_label.PNG
#   inflating: data/Class1/Train/Label/0735_label.PNG
#   inflating: data/Class1/Train/Label/0818_label.PNG
#   inflating: data/Class1/Train/Label/0673_label.PNG
#   inflating: data/Class1/Train/Label/0997_label.PNG
#   inflating: data/Class1/Train/Label/0983_label.PNG
#   inflating: data/Class1/Train/Label/0667_label.PNG
#   inflating: data/Class1/Train/Label/0721_label.PNG
#   inflating: data/Class1/Train/Label/0876_label.PNG
#   inflating: data/Class1/Train/Label/0792_label.PNG
#   inflating: data/Class1/Train/Label/0930_label.PNG
#   inflating: data/Class1/Train/Label/1107_label.PNG
#   inflating: data/Class1/Train/Label/1041_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1041_label.PNG
#   inflating: data/Class1/Train/Label/1088_label.PNG
#   inflating: data/Class1/Train/Label/1017_label.PNG
#   inflating: data/Class1/Train/Label/0820_label.PNG
#   inflating: data/Class1/Train/Label/0966_label.PNG
#   inflating: data/Class1/Train/Label/0682_label.PNG
#   inflating: data/Class1/Train/Label/0631_label.PNG
#   inflating: data/Class1/Train/Label/0893_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0893_label.PNG
#   inflating: data/Class1/Train/Label/0588_label.PNG
#   inflating: data/Class1/Train/Label/0777_label.PNG
#   inflating: data/Class1/Train/Label/0763_label.PNG
#   inflating: data/Class1/Train/Label/0887_label.PNG
#   inflating: data/Class1/Train/Label/0625_label.PNG
#   inflating: data/Class1/Train/Label/0908_label.PNG
#   inflating: data/Class1/Train/Label/1079_label.PNG
#   inflating: data/Class1/Train/Label/0696_label.PNG
#   inflating: data/Class1/Train/Label/0972_label.PNG
#   inflating: data/Class1/Train/Label/0719_label.PNG
#   inflating: data/Class1/Train/Label/0834_label.PNG
#   inflating: data/Class1/Train/Label/1003_label.PNG
#   inflating: data/Class1/Train/Label/1145_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1145_label.PNG
#   inflating: data/Class1/Train/Label/0742_label.PNG
#   inflating: data/Class1/Train/Label/0929_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0929_label.PNG
#   inflating: data/Class1/Train/Label/0604_label.PNG
#   inflating: data/Class1/Train/Label/1091_label.PNG
#   inflating: data/Class1/Train/Label/1058_label.PNG
#   inflating: data/Class1/Train/Label/0953_label.PNG
#   inflating: data/Class1/Train/Label/0815_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0815_label.PNG
#   inflating: data/Class1/Train/Label/0738_label.PNG
#   inflating: data/Class1/Train/Label/1022_label.PNG
#   inflating: data/Class1/Train/Label/1036_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1036_label.PNG
#   inflating: data/Class1/Train/Label/0801_label.PNG
#   inflating: data/Class1/Train/Label/0947_label.PNG
#   inflating: data/Class1/Train/Label/1085_label.PNG
#   inflating: data/Class1/Train/Label/0610_label.PNG
#   inflating: data/Class1/Train/Label/0756_label.PNG
#   inflating: data/Class1/Train/Label/0711_label.PNG
#   inflating: data/Class1/Train/Label/0657_label.PNG
#   inflating: data/Class1/Train/Label/0900_label.PNG
#   inflating: data/Class1/Train/Label/0846_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0846_label.PNG
#   inflating: data/Class1/Train/Label/0594_label.PNG
#   inflating: data/Class1/Train/Label/1071_label.PNG
#   inflating: data/Class1/Train/Label/1137_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1137_label.PNG
#   inflating: data/Class1/Train/Label/1123_label.PNG
#   inflating: data/Class1/Train/Label/1065_label.PNG
#   inflating: data/Class1/Train/Label/0580_label.PNG
#   inflating: data/Class1/Train/Label/0852_label.PNG
#   inflating: data/Class1/Train/Label/0639_label.PNG
#   inflating: data/Class1/Train/Label/0914_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0914_label.PNG
#   inflating: data/Class1/Train/Label/Labels.txt
#   inflating: __MACOSX/data/Class1/Train/Label/._Labels.txt
#   inflating: data/Class1/Train/Label/0643_label.PNG
#   inflating: data/Class1/Train/Label/0705_label.PNG
#   inflating: data/Class1/Train/Label/0828_label.PNG
#   inflating: data/Class1/Train/Label/1102_label.PNG
#   inflating: data/Class1/Train/Label/1044_label.PNG
#   inflating: data/Class1/Train/Label/0873_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0873_label.PNG
#   inflating: data/Class1/Train/Label/0797_label.PNG
#   inflating: data/Class1/Train/Label/0935_label.PNG
#   inflating: data/Class1/Train/Label/0618_label.PNG
#   inflating: data/Class1/Train/Label/0986_label.PNG
#   inflating: data/Class1/Train/Label/0662_label.PNG
#   inflating: data/Class1/Train/Label/0809_label.PNG
#   inflating: data/Class1/Train/Label/0724_label.PNG
#   inflating: data/Class1/Train/Label/0730_label.PNG
#   inflating: data/Class1/Train/Label/0676_label.PNG
#   inflating: data/Class1/Train/Label/0992_label.PNG
#   inflating: data/Class1/Train/Label/0921_label.PNG
#   inflating: data/Class1/Train/Label/0783_label.PNG
#   inflating: data/Class1/Train/Label/0867_label.PNG
#   inflating: data/Class1/Train/Label/1050_label.PNG
#   inflating: data/Class1/Train/Label/1099_label.PNG
#   inflating: data/Class1/Train/Label/1116_label.PNG
#   inflating: data/Class1/Train/Label/1006_label.PNG
#   inflating: data/Class1/Train/Label/1140_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._1140_label.PNG
#   inflating: data/Class1/Train/Label/0693_label.PNG
#   inflating: data/Class1/Train/Label/0977_label.PNG
#   inflating: data/Class1/Train/Label/0831_label.PNG
#   inflating: data/Class1/Train/Label/0766_label.PNG
#   inflating: data/Class1/Train/Label/0599_label.PNG
#   inflating: data/Class1/Train/Label/0882_label.PNG
#   inflating: data/Class1/Train/Label/0620_label.PNG
#   inflating: data/Class1/Train/Label/0919_label.PNG
#   inflating: data/Class1/Train/Label/0634_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0634_label.PNG
#   inflating: data/Class1/Train/Label/0896_label.PNG
#   inflating: data/Class1/Train/Label/0772_label.PNG
#   inflating: data/Class1/Train/Label/1068_label.PNG
#   inflating: data/Class1/Train/Label/0825_label.PNG
#   inflating: data/Class1/Train/Label/0708_label.PNG
#   inflating: data/Class1/Train/Label/0963_label.PNG
#   inflating: data/Class1/Train/Label/0687_label.PNG
#   inflating: data/Class1/Train/Label/1012_label.PNG
#   inflating: data/Class1/Train/Label/0615_label.PNG
#   inflating: data/Class1/Train/Label/0938_label.PNG
#   inflating: data/Class1/Train/Label/0753_label.PNG
#   inflating: data/Class1/Train/Label/1080_label.PNG
#   inflating: data/Class1/Train/Label/1049_label.PNG
#   inflating: data/Class1/Train/Label/0729_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0729_label.PNG
#   inflating: data/Class1/Train/Label/0804_label.PNG
#   inflating: data/Class1/Train/Label/0942_label.PNG
#   inflating: __MACOSX/data/Class1/Train/Label/._0942_label.PNG
#   inflating: data/Class1/Train/Label/1033_label.PNG
#   inflating: data/Class1/Train/Label/1027_label.PNG
#   inflating: data/Class1/Train/Label/0956_label.PNG
#   inflating: data/Class1/Train/Label/0810_label.PNG
#   inflating: data/Class1/Train/Label/1094_label.PNG
# ...
#   inflating: __MACOSX/data/Class6/Train/._1128.PNG
#   inflating: data/Class6/Train/0578.PNG
#   inflating: __MACOSX/data/Class6/Train/._0578.PNG
#   inflating: data/Class6/Train/1100.PNG
#   inflating: __MACOSX/data/Class6/Train/._1100.PNG
#   inflating: data/Class6/Train/1114.PNG
#   inflating: __MACOSX/data/Class6/Train/._1114.PNG
#   inflating: data/Class6/Train/0587.PNG
#   inflating: __MACOSX/data/Class6/Train/._0587.PNG
#   inflating: data/Class6/Train/0593.PNG
#   inflating: __MACOSX/data/Class6/Train/._0593.PNG
#   inflating: data/Class6/Train/0585.PNG
#   inflating: __MACOSX/data/Class6/Train/._0585.PNG
#   inflating: data/Class6/Train/0591.PNG
#   inflating: __MACOSX/data/Class6/Train/._0591.PNG
#   inflating: data/Class6/Train/1102.PNG
#   inflating: __MACOSX/data/Class6/Train/._1102.PNG
#   inflating: data/Class6/Train/1116.PNG
#   inflating: __MACOSX/data/Class6/Train/._1116.PNG
#   inflating: data/Class6/Train/0963.PNG
#   inflating: __MACOSX/data/Class6/Train/._0963.PNG
#   inflating: data/Class6/Train/0977.PNG
#   inflating: __MACOSX/data/Class6/Train/._0977.PNG
#   inflating: data/Class6/Train/0787.PNG
#   inflating: __MACOSX/data/Class6/Train/._0787.PNG
#   inflating: data/Class6/Train/0793.PNG
#   inflating: __MACOSX/data/Class6/Train/._0793.PNG
#   inflating: data/Class6/Train/0778.PNG
#   inflating: __MACOSX/data/Class6/Train/._0778.PNG
#   inflating: data/Class6/Train/0744.PNG
#   inflating: __MACOSX/data/Class6/Train/._0744.PNG
#   inflating: data/Class6/Train/0988.PNG
#   inflating: __MACOSX/data/Class6/Train/._0988.PNG
#   inflating: data/Class6/Train/0750.PNG
#   inflating: __MACOSX/data/Class6/Train/._0750.PNG
#   inflating: data/Class6/Train/0817.PNG
#   inflating: __MACOSX/data/Class6/Train/._0817.PNG
#   inflating: data/Class6/Train/0803.PNG
#   inflating: __MACOSX/data/Class6/Train/._0803.PNG
#   inflating: data/Class6/Train/0618.PNG
#   inflating: __MACOSX/data/Class6/Train/._0618.PNG
#   inflating: data/Class6/Train/0630.PNG
#   inflating: __MACOSX/data/Class6/Train/._0630.PNG
#   inflating: data/Class6/Train/0624.PNG
#   inflating: __MACOSX/data/Class6/Train/._0624.PNG
#   inflating: data/Class6/Train/1089.PNG
#   inflating: __MACOSX/data/Class6/Train/._1089.PNG
#   inflating: data/Class6/Train/1076.PNG
#   inflating: __MACOSX/data/Class6/Train/._1076.PNG
#   inflating: data/Class6/Train/1062.PNG
#   inflating: __MACOSX/data/Class6/Train/._1062.PNG
#   inflating: data/Class6/Train/1063.PNG
#   inflating: __MACOSX/data/Class6/Train/._1063.PNG
#   inflating: data/Class6/Train/1077.PNG
#   inflating: __MACOSX/data/Class6/Train/._1077.PNG
#   inflating: data/Class6/Train/1088.PNG
#   inflating: __MACOSX/data/Class6/Train/._1088.PNG
#   inflating: data/Class6/Train/0625.PNG
#   inflating: __MACOSX/data/Class6/Train/._0625.PNG
#   inflating: data/Class6/Train/0631.PNG
#   inflating: __MACOSX/data/Class6/Train/._0631.PNG
#   inflating: data/Class6/Train/0619.PNG
#   inflating: __MACOSX/data/Class6/Train/._0619.PNG
#   inflating: data/Class6/Train/0802.PNG
#   inflating: __MACOSX/data/Class6/Train/._0802.PNG
#   inflating: data/Class6/Train/0816.PNG
#   inflating: __MACOSX/data/Class6/Train/._0816.PNG
#   inflating: data/Class6/Train/0751.PNG
#   inflating: __MACOSX/data/Class6/Train/._0751.PNG
#   inflating: data/Class6/Train/0989.PNG
#   inflating: __MACOSX/data/Class6/Train/._0989.PNG
#   inflating: data/Class6/Train/0745.PNG
#   inflating: __MACOSX/data/Class6/Train/._0745.PNG
#   inflating: data/Class6/Train/0779.PNG
#   inflating: __MACOSX/data/Class6/Train/._0779.PNG
#   inflating: data/Class6/Train/0792.PNG
#   inflating: __MACOSX/data/Class6/Train/._0792.PNG
#   inflating: data/Class6/Train/0786.PNG
#   inflating: __MACOSX/data/Class6/Train/._0786.PNG
#   inflating: data/Class6/Train/0976.PNG
#   inflating: __MACOSX/data/Class6/Train/._0976.PNG
#   inflating: data/Class6/Train/0962.PNG
#   inflating: __MACOSX/data/Class6/Train/._0962.PNG
#   inflating: data/Class6/Train/1117.PNG
#   inflating: __MACOSX/data/Class6/Train/._1117.PNG
#   inflating: data/Class6/Train/1103.PNG
#   inflating: __MACOSX/data/Class6/Train/._1103.PNG
#   inflating: data/Class6/Train/0590.PNG
#   inflating: __MACOSX/data/Class6/Train/._0590.PNG
#   inflating: data/Class6/Train/0584.PNG
#   inflating: __MACOSX/data/Class6/Train/._0584.PNG
#   inflating: data/Class6/Train/0939.PNG
#   inflating: __MACOSX/data/Class6/Train/._0939.PNG
#   inflating: data/Class6/Train/0905.PNG
#   inflating: __MACOSX/data/Class6/Train/._0905.PNG
#   inflating: data/Class6/Train/0911.PNG
#   inflating: __MACOSX/data/Class6/Train/._0911.PNG
#   inflating: data/Class6/Train/0722.PNG
#   inflating: __MACOSX/data/Class6/Train/._0722.PNG
#   inflating: data/Class6/Train/0736.PNG
#   inflating: __MACOSX/data/Class6/Train/._0736.PNG
#   inflating: data/Class6/Train/0695.PNG
#   inflating: __MACOSX/data/Class6/Train/._0695.PNG
#   inflating: data/Class6/Train/0859.PNG
#   inflating: __MACOSX/data/Class6/Train/._0859.PNG
#   inflating: data/Class6/Train/0681.PNG
#   inflating: __MACOSX/data/Class6/Train/._0681.PNG
#   inflating: data/Class6/Train/0871.PNG
#   inflating: __MACOSX/data/Class6/Train/._0871.PNG
#   inflating: data/Class6/Train/0865.PNG
#   inflating: __MACOSX/data/Class6/Train/._0865.PNG
#   inflating: data/Class6/Train/0656.PNG
#   inflating: __MACOSX/data/Class6/Train/._0656.PNG
#   inflating: data/Class6/Train/0642.PNG
#   inflating: __MACOSX/data/Class6/Train/._0642.PNG
#   inflating: data/Class6/Train/1038.PNG
#   inflating: __MACOSX/data/Class6/Train/._1038.PNG
#   inflating: data/Class6/Train/1010.PNG
#   inflating: __MACOSX/data/Class6/Train/._1010.PNG
#   inflating: data/Class6/Train/1004.PNG
#   inflating: __MACOSX/data/Class6/Train/._1004.PNG
#   inflating: data/Class6/Train/1005.PNG
#   inflating: __MACOSX/data/Class6/Train/._1005.PNG
#   inflating: data/Class6/Train/1011.PNG
#   inflating: __MACOSX/data/Class6/Train/._1011.PNG
#   inflating: data/Class6/Train/1039.PNG
#   inflating: __MACOSX/data/Class6/Train/._1039.PNG
#   inflating: data/Class6/Train/0643.PNG
#   inflating: __MACOSX/data/Class6/Train/._0643.PNG
#   inflating: data/Class6/Train/0657.PNG
#   inflating: __MACOSX/data/Class6/Train/._0657.PNG
#   inflating: data/Class6/Train/0864.PNG
#   inflating: __MACOSX/data/Class6/Train/._0864.PNG
#   inflating: data/Class6/Train/0870.PNG
#   inflating: __MACOSX/data/Class6/Train/._0870.PNG
#   inflating: data/Class6/Train/0680.PNG
#   inflating: __MACOSX/data/Class6/Train/._0680.PNG
#   inflating: data/Class6/Train/0858.PNG
#   inflating: __MACOSX/data/Class6/Train/._0858.PNG
#   inflating: data/Class6/Train/0694.PNG
#   inflating: __MACOSX/data/Class6/Train/._0694.PNG
#   inflating: data/Class6/Train/0737.PNG
#   inflating: __MACOSX/data/Class6/Train/._0737.PNG
#   inflating: data/Class6/Train/0723.PNG
#   inflating: __MACOSX/data/Class6/Train/._0723.PNG
#   inflating: data/Class6/Train/0910.PNG
#   inflating: __MACOSX/data/Class6/Train/._0910.PNG
#   inflating: data/Class6/Train/0904.PNG
#   inflating: __MACOSX/data/Class6/Train/._0904.PNG
#   inflating: data/Class6/Train/0938.PNG
#   inflating: __MACOSX/data/Class6/Train/._0938.PNG
#   inflating: data/Class6/Train/0912.PNG
#   inflating: __MACOSX/data/Class6/Train/._0912.PNG
#   inflating: data/Class6/Train/0906.PNG
#   inflating: __MACOSX/data/Class6/Train/._0906.PNG
#   inflating: data/Class6/Train/0735.PNG
#   inflating: __MACOSX/data/Class6/Train/._0735.PNG
#   inflating: data/Class6/Train/0721.PNG
#   inflating: __MACOSX/data/Class6/Train/._0721.PNG
#   inflating: data/Class6/Train/0709.PNG
#   inflating: __MACOSX/data/Class6/Train/._0709.PNG
#   inflating: data/Class6/Train/0682.PNG
#   inflating: __MACOSX/data/Class6/Train/._0682.PNG
#   inflating: data/Class6/Train/0696.PNG
#   inflating: __MACOSX/data/Class6/Train/._0696.PNG
#   inflating: data/Class6/Train/0866.PNG
#   inflating: __MACOSX/data/Class6/Train/._0866.PNG
#   inflating: data/Class6/Train/0872.PNG
#   inflating: __MACOSX/data/Class6/Train/._0872.PNG
#   inflating: data/Class6/Train/0641.PNG
#   inflating: __MACOSX/data/Class6/Train/._0641.PNG
#   inflating: data/Class6/Train/0899.PNG
#   inflating: __MACOSX/data/Class6/Train/._0899.PNG
#   inflating: data/Class6/Train/0655.PNG
#   inflating: __MACOSX/data/Class6/Train/._0655.PNG
#   inflating: data/Class6/Train/0669.PNG
#   inflating: __MACOSX/data/Class6/Train/._0669.PNG
#   inflating: data/Class6/Train/1007.PNG
#   inflating: __MACOSX/data/Class6/Train/._1007.PNG
#   inflating: data/Class6/Train/1013.PNG
#   inflating: __MACOSX/data/Class6/Train/._1013.PNG
#   inflating: data/Class6/Train/1012.PNG
#   inflating: __MACOSX/data/Class6/Train/._1012.PNG
#   inflating: data/Class6/Train/1006.PNG
#   inflating: __MACOSX/data/Class6/Train/._1006.PNG
#   inflating: data/Class6/Train/0668.PNG
#   inflating: __MACOSX/data/Class6/Train/._0668.PNG
#   inflating: data/Class6/Train/0654.PNG
#   inflating: __MACOSX/data/Class6/Train/._0654.PNG
#   inflating: data/Class6/Train/0898.PNG
#   inflating: __MACOSX/data/Class6/Train/._0898.PNG
#   inflating: data/Class6/Train/0640.PNG
#   inflating: __MACOSX/data/Class6/Train/._0640.PNG
#   inflating: data/Class6/Train/0873.PNG
#   inflating: __MACOSX/data/Class6/Train/._0873.PNG
#   inflating: data/Class6/Train/0867.PNG
#   inflating: __MACOSX/data/Class6/Train/._0867.PNG
#   inflating: data/Class6/Train/0697.PNG
#   inflating: __MACOSX/data/Class6/Train/._0697.PNG
#   inflating: data/Class6/Train/0683.PNG
#   inflating: __MACOSX/data/Class6/Train/._0683.PNG
#   inflating: data/Class6/Train/0708.PNG
#   inflating: __MACOSX/data/Class6/Train/._0708.PNG
#   inflating: data/Class6/Train/0720.PNG
#   inflating: __MACOSX/data/Class6/Train/._0720.PNG
#   inflating: data/Class6/Train/0734.PNG
#   inflating: __MACOSX/data/Class6/Train/._0734.PNG
#   inflating: data/Class6/Train/0907.PNG
#   inflating: __MACOSX/data/Class6/Train/._0907.PNG
#   inflating: data/Class6/Train/0913.PNG
#   inflating: __MACOSX/data/Class6/Train/._0913.PNG
#   inflating: data/Class6/Train/0917.PNG
#   inflating: __MACOSX/data/Class6/Train/._0917.PNG
#   inflating: data/Class6/Train/0903.PNG
#   inflating: __MACOSX/data/Class6/Train/._0903.PNG
#   inflating: data/Class6/Train/0718.PNG
#   inflating: __MACOSX/data/Class6/Train/._0718.PNG
#   inflating: data/Class6/Train/0730.PNG
#   inflating: __MACOSX/data/Class6/Train/._0730.PNG
#   inflating: data/Class6/Train/0724.PNG
#   inflating: __MACOSX/data/Class6/Train/._0724.PNG
#   inflating: data/Class6/Train/0863.PNG
#   inflating: __MACOSX/data/Class6/Train/._0863.PNG
#   inflating: data/Class6/Train/0877.PNG
#   inflating: __MACOSX/data/Class6/Train/._0877.PNG
#   inflating: data/Class6/Train/0687.PNG
#   inflating: __MACOSX/data/Class6/Train/._0687.PNG
#   inflating: data/Class6/Train/0693.PNG
#   inflating: __MACOSX/data/Class6/Train/._0693.PNG
#   inflating: data/Class6/Train/0678.PNG
#   inflating: __MACOSX/data/Class6/Train/._0678.PNG
#   inflating: data/Class6/Train/0644.PNG
#   inflating: __MACOSX/data/Class6/Train/._0644.PNG
#   inflating: data/Class6/Train/0650.PNG
#   inflating: __MACOSX/data/Class6/Train/._0650.PNG
#   inflating: data/Class6/Train/0888.PNG
#   inflating: __MACOSX/data/Class6/Train/._0888.PNG
#   inflating: data/Class6/Train/1002.PNG
#   inflating: __MACOSX/data/Class6/Train/._1002.PNG
#   inflating: data/Class6/Train/1016.PNG
#   inflating: __MACOSX/data/Class6/Train/._1016.PNG
#   inflating: data/Class6/Train/1017.PNG
#   inflating: __MACOSX/data/Class6/Train/._1017.PNG
#   inflating: data/Class6/Train/1003.PNG
#   inflating: __MACOSX/data/Class6/Train/._1003.PNG
#   inflating: data/Class6/Train/0889.PNG
#   inflating: __MACOSX/data/Class6/Train/._0889.PNG
#   inflating: data/Class6/Train/0651.PNG
#   inflating: __MACOSX/data/Class6/Train/._0651.PNG
#   inflating: data/Class6/Train/0645.PNG
#   inflating: __MACOSX/data/Class6/Train/._0645.PNG
#   inflating: data/Class6/Train/0679.PNG
#   inflating: __MACOSX/data/Class6/Train/._0679.PNG
#   inflating: data/Class6/Train/0692.PNG
#   inflating: __MACOSX/data/Class6/Train/._0692.PNG
#   inflating: data/Class6/Train/0686.PNG
#   inflating: __MACOSX/data/Class6/Train/._0686.PNG
#   inflating: data/Class6/Train/0876.PNG
#   inflating: __MACOSX/data/Class6/Train/._0876.PNG
#   inflating: data/Class6/Train/0862.PNG
#   inflating: __MACOSX/data/Class6/Train/._0862.PNG
#   inflating: data/Class6/Train/0725.PNG
#   inflating: __MACOSX/data/Class6/Train/._0725.PNG
#   inflating: data/Class6/Train/0731.PNG
#   inflating: __MACOSX/data/Class6/Train/._0731.PNG
#   inflating: data/Class6/Train/0719.PNG
#   inflating: __MACOSX/data/Class6/Train/._0719.PNG
#   inflating: data/Class6/Train/0902.PNG
#   inflating: __MACOSX/data/Class6/Train/._0902.PNG
#   inflating: data/Class6/Train/0916.PNG
#   inflating: __MACOSX/data/Class6/Train/._0916.PNG
#   inflating: data/Class6/Train/1149.PNG
#   inflating: __MACOSX/data/Class6/Train/._1149.PNG
#   inflating: data/Class6/Train/0900.PNG
#   inflating: __MACOSX/data/Class6/Train/._0900.PNG
#   inflating: data/Class6/Train/0914.PNG
#   inflating: __MACOSX/data/Class6/Train/._0914.PNG
#   inflating: data/Class6/Train/0928.PNG
#   inflating: __MACOSX/data/Class6/Train/._0928.PNG
#   inflating: data/Class6/Train/0727.PNG
#   inflating: __MACOSX/data/Class6/Train/._0727.PNG
#   inflating: data/Class6/Train/0733.PNG
#   inflating: __MACOSX/data/Class6/Train/._0733.PNG
#   inflating: data/Class6/Train/0874.PNG
#   inflating: __MACOSX/data/Class6/Train/._0874.PNG
#   inflating: data/Class6/Train/0860.PNG
#   inflating: __MACOSX/data/Class6/Train/._0860.PNG
#   inflating: data/Class6/Train/0848.PNG
#   inflating: __MACOSX/data/Class6/Train/._0848.PNG
#   inflating: data/Class6/Train/0690.PNG
#   inflating: __MACOSX/data/Class6/Train/._0690.PNG
#   inflating: data/Class6/Train/0684.PNG
#   inflating: __MACOSX/data/Class6/Train/._0684.PNG
#   inflating: data/Class6/Train/0653.PNG
#   inflating: __MACOSX/data/Class6/Train/._0653.PNG
#   inflating: data/Class6/Train/0647.PNG
#   inflating: __MACOSX/data/Class6/Train/._0647.PNG
#   inflating: data/Class6/Train/1015.PNG
#   inflating: __MACOSX/data/Class6/Train/._1015.PNG
#   inflating: data/Class6/Train/1001.PNG
#   inflating: __MACOSX/data/Class6/Train/._1001.PNG
#   inflating: data/Class6/Train/1029.PNG
#   inflating: __MACOSX/data/Class6/Train/._1029.PNG
#   inflating: data/Class6/Train/1028.PNG
#   inflating: __MACOSX/data/Class6/Train/._1028.PNG
#   inflating: data/Class6/Train/1000.PNG
#   inflating: __MACOSX/data/Class6/Train/._1000.PNG
#   inflating: data/Class6/Train/1014.PNG
#   inflating: __MACOSX/data/Class6/Train/._1014.PNG
#   inflating: data/Class6/Train/0646.PNG
#   inflating: __MACOSX/data/Class6/Train/._0646.PNG
#   inflating: data/Class6/Train/0652.PNG
#   inflating: __MACOSX/data/Class6/Train/._0652.PNG
#   inflating: data/Class6/Train/0685.PNG
#   inflating: __MACOSX/data/Class6/Train/._0685.PNG
#   inflating: data/Class6/Train/0691.PNG
#   inflating: __MACOSX/data/Class6/Train/._0691.PNG
#   inflating: data/Class6/Train/0849.PNG
#   inflating: __MACOSX/data/Class6/Train/._0849.PNG
#   inflating: data/Class6/Train/0861.PNG
#   inflating: __MACOSX/data/Class6/Train/._0861.PNG
#   inflating: data/Class6/Train/0875.PNG
#   inflating: __MACOSX/data/Class6/Train/._0875.PNG
#   inflating: data/Class6/Train/0732.PNG
#   inflating: __MACOSX/data/Class6/Train/._0732.PNG
#   inflating: data/Class6/Train/0726.PNG
#   inflating: __MACOSX/data/Class6/Train/._0726.PNG
#   inflating: data/Class6/Train/0929.PNG
#   inflating: __MACOSX/data/Class6/Train/._0929.PNG
#   inflating: data/Class6/Train/0915.PNG
#   inflating: __MACOSX/data/Class6/Train/._0915.PNG
#   inflating: data/Class6/Train/0901.PNG
#   inflating: __MACOSX/data/Class6/Train/._0901.PNG
#   inflating: data/Class6/Train/1148.PNG
#   inflating: __MACOSX/data/Class6/Train/._1148.PNG
#   inflating: __MACOSX/data/Class6/._Train
#   inflating: __MACOSX/data/._Class6

# %%
# You should be able to see 7 Classes here
# !ls data
# Out:
# Class1	Class2	Class3	Class4	Class5	Class6	Class7

# %% [markdown]
# Sample Output : Class1 Class2	Class3	Class4	Class5	Class6	Class7

# %% [markdown]
# # Main Notebook

# %%
import os
import sys
import time
import warnings
from random import shuffle

# %tensorflow_version 1.x

import numpy as np
import pandas as pd
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.optimizers import Adam
from tensorflow.python.lib.io import file_io
from skimage.transform import resize
import numpy as np
import keras
from keras import backend as K
import cv2
from sklearn.model_selection import train_test_split

warnings.filterwarnings("ignore")
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %% [markdown]
# # Data Loading

# %%
# Not all data in the dataset has defects. We only use the images which have defects
# This function takes the dataset_type as a parameter. You can pass "Train" or "Test"
# as argument to get the appropriate dataset
def load_data(dataset_type="Train"):
    file_list = {}
    defect_map = {}
    file_name = []
    file_mask = []
    count = 0
    num_classes = 6

    data_dir = "data"
    for x in range(1, num_classes + 1):
        path = os.path.join(os.path.join(data_dir, "Class" + str(x)), dataset_type)
        df = pd.read_fwf(path + "/Label/Labels.txt")
        count = 0
        for i in range(0, len(df)):
            curr_file = path + "/" + str(df.iloc[i][2])
            if (df.iloc[i][1] == 1):
                file_list[curr_file] = path + "/Label/" + str(df.iloc[i][4])
                defect_map[curr_file] = 1
            else:
                fnametest = str(df.iloc[i][2]).split(".")
                file_list[curr_file] = str(path + "/Label/" + fnametest[0] + "_label.PNG")
                defect_map[curr_file] = 0

    items = list(file_list.keys())
    shuffle(items)
    for key in items:
        if ((not os.path.exists(key)) or (not os.path.exists(file_list[key]))):
            # print ("Missing mask for ", key)
            continue

        if defect_map[key] == 1:
            file_name.append(key)
            file_mask.append(file_list[key])
        elif count < 80 * num_classes:
            file_name.append(key)
            file_mask.append(file_list[key])
            count = count + 1

    return file_name, file_mask

# %% [markdown]
# Since the dataset is so large that it cannot fit into memory, we will need to use generator functions to iteratively load the dataset

# %%
# This is generator class to process data in batches and send them for training
class Surface_Generator(keras.utils.Sequence):

    def __init__(self, image_filenames, labels, batch_size, test=False):
        self.image_filenames, self.labels = image_filenames, labels
        self.batch_size = batch_size

    # return the total number of batches you have i.e., total_files/batch_size
    def __len__(self):
        # YOUR CODE HERE
        length = self.image_filenames
        batchsize = self.batch_size
        num = int(len(length)/batchsize)
        return num + 1

    # this function is called for every mini-batch to get the images/masks for that mini-batch
    def __getitem__(self, idx):
        batch_x = self.image_filenames[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.labels[idx * self.batch_size:(idx + 1) * self.batch_size]
        image_arr = []
        mask_arr = []
        # Open a batch of images and their corresponding masks using cv2.imread
        # resize them to 512x512x1 and return an np.array of images and masks
        for image in batch_x:
          image_arr.append(resize(cv2.imread(image,0), (512, 512, 1)))
        for mask in batch_y:
          mask_arr.append(resize(cv2.imread(mask,0), (512, 512, 1)))

        return np.array(image_arr).astype(np.float32), np.array(mask_arr).astype(np.float32)
    
    # for testing we need to get the list of all true masks
    # this function should return all the labels in the dataset set 
    # we will call this function only for the "Test" dataset
    def get_all_masks(self):
        mask_arr = []
        
        for mask in self.labels:
          mask_arr.append(resize(cv2.imread(mask), (512, 512, 1)))

        return np.array(mask_arr).astype(np.float32)

# %%
# Since we already have a split for training and test set,
# we just need to split training set to get a validation set

# Load training data
X, Y = load_data("Train")

# %%
# Split the original training data to get training and validation set
# to get X_train, X_val, y_train, y_val
X_train, X_val, y_train, y_val = train_test_split(X, Y, test_size=0.2, random_state=0)


# Convert to numpy arrays
X_train = np.array(X_train)
X_val = np.array(X_val)
y_train = np.array(y_train)
y_val = np.array(y_val)

print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (740,) (740,) (186,) (186,)

# %% [markdown]
# The output shape after the split should be
# (740,) (740,) (186,) (186,)

# %%
# Free memory
import gc
del X
del Y
gc.collect()
# Out:
# 358

# %% [markdown]
# # Metrics
#
# Use keras.backend to calculate dice coefficient metric and dice coefficient loss function.
#
# Recall that dice_coeff = 2 \* intersection / union
#
# We add a smoothing parameter and modify the formula to
#
# dice_coeff = 2 \* (intersection + smooth) / (union + smooth)
#
# Our objective is to make dice_coeff as close to 1.0 as possible.
# Define and use the appropriate loss function.

# %%
# Dice Coefficient metric
def dice_coef(y_true, y_pred):
    smooth = 1
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth)/(K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


# Dice Coefficient loss
def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %% [markdown]
# # Model
#
# U-net architeture has proved to be very powerful for segmentation tasks.
#
# We will be creating a Unet model based on the paper :
#
# [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/pdf/1505.04597.pdf)
#
# ---
#
# A picture of the architecture we plan to use is provided in the project description pdf.
#
# We will create a Convolutional block module to help us build the model.
#
# Each convolutional block module will contain two trainable layers.
#
# Each layer will be a Convolution operation followed by batch normalization with relu activation.
#
#
#
# The U-net architecture has a contracting path, a convolution and then an expansive path.
#
# We will use instances of the convolutional block to create the contracting and expansive path.

# %%
from keras.layers import Conv2DTranspose, Dropout, Activation, BatchNormalization, UpSampling2D, Concatenate
from keras.layers import Input, Conv2D, MaxPooling2D, concatenate
from keras.models import Model

# Create a 2D convolution block. We will use multiple instances of this block to build our U-net model
# This block will contain two layers. 
# Each layer will be a Convolution operation followed by batch normalization with relu activation 
def conv2d_block(input_tensor, n_filters, kernel_size):
    # first layer
    # Create a Conv2D layer with n_filters and a kernel of dimension : kernel_size x kernel_size. 
    # Use same padding and he_normal initializer
    # YOUR CODE HERE
    x = Conv2D(n_filters, (kernel_size,kernel_size), padding="same", kernel_initializer="glorot_uniform")(input_tensor)
    
    # add a BatchNormalization layer
    # YOUR CODE HERE
    x = BatchNormalization()(x)
        
    # Add a relu non-linearity (keras.layers.Activation)
    # YOUR CODE HERE
    x = x = Activation('relu')(x)
    
    # second layer
    # repeat the above steps (Conv + batchnorm + relu) taking the output of relu layer as input for this convolutional layer
    # YOUR CODE HERE
    x = Conv2D(n_filters, (kernel_size,kernel_size), padding="same", kernel_initializer="glorot_uniform")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # return the output tensor
    return x


def get_unet_model(n_filters=16, dropout_prob=0.5, kernel_size=3):
    input_img = Input((512, 512, 1))
    
    # contracting path
    # create a convolutional block with input_img as the input tensor and n_filters
    # YOUR CODE HERE
    c1 = conv2d_block(input_img, n_filters,kernel_size)

    # apply a 2d maxpooling with a pool size of 2x2
    # YOUR CODE HERE
    p1 = MaxPooling2D((2,2))(c1)

    # add a dropout. Since this the input, set the dropout rate to 0.5 * dropout_prob
    # YOUR CODE HERE
    p1 = Dropout(0.5*dropout_prob)(p1)


    # create another convolutional block. this time use p1 as input tensor and twice the n_filters
    # repeat the same maxpool and dropout but set dropout rate to dropout_prob this time
    # YOUR CODE HERE
    c2 = conv2d_block(p1, 2*n_filters,kernel_size)
    p2 = MaxPooling2D((2,2))(c2)
    p2 = Dropout(dropout_prob)(p2)

    # create another block with maxpool and dropout with 4 x n_filters
    # YOUR CODE HERE
    c3 = conv2d_block(p2, 4*n_filters,kernel_size)
    p3 = MaxPooling2D((2,2))(c3)
    p3 = Dropout(dropout_prob)(p3)

    # create another block with maxpool and dropout with 8 x n_filters
    # YOUR CODE HERE
    c4 = conv2d_block(p3, 8*n_filters,kernel_size)
    p4 = MaxPooling2D((2,2))(c4)
    p4 = Dropout(dropout_prob)(p4)


    # This is the layer where we combine the contractive and expansive paths
    # create a convolutional block with 16 x n_filters. No pooling/dropout this time
    # YOUR CODE HERE
    c5 = conv2d_block(p4, 16*n_filters,kernel_size)

    
    # Expansive path

    # We will create a similar structure as the contracting path but instead of 
    # convolutional operation, we will use Deconvolution operations

    # Create a Conv2DTranspose layer (deconvolution) with 8 x n_filters, kernel_size, 
    # 2x2 strides and same padding
    # YOUR CODE HERE
    u6 = Conv2DTranspose(8*n_filters, kernel_size, strides=(2, 2), padding="same")(c5)

    # Concatenate u6 and c4 using keras.layers.concatenate
    # YOUR CODE HERE
    u6 = concatenate([u6, c4])
    
    # dropout
    # YOUR CODE HERE
    u6 = Dropout(dropout_prob)(u6)
    
    # create a convolutional block with 8 x n_filters
    # YOUR CODE HERE
    c6 = conv2d_block(u6, 8*n_filters,kernel_size)
    

    # Create a similar module as previous, deconv, concatenate, dropout, conv2d_block
    # Please ensure that the number of filters you use match the n_filters of 
    # the layer you are concatenating with
    # YOUR CODE HERE
    u7 = Conv2DTranspose(4*n_filters, kernel_size, strides=(2, 2), padding="same")(c4)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout_prob)(u7)
    c7 = conv2d_block(u7, 4*n_filters,kernel_size)
    
    # Create a similar module as previous, deconv, concatenate, dropout, conv2d_block
    # YOUR CODE HERE
    u8 = Conv2DTranspose(2*n_filters, kernel_size, strides=(2, 2), padding="same")(c3)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout_prob)(u8)
    c8 = conv2d_block(u8, 2*n_filters,kernel_size)


    # Create a similar module as previous, deconv, concatenate, dropout, conv2d_block
    # YOUR CODE HERE
    u9 = Conv2DTranspose(n_filters, kernel_size, strides=(2, 2), padding="same")(c2)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout_prob)(u9)
    c9 = conv2d_block(u9, n_filters,kernel_size)

    # apply a 1x1 convolution on c9 to get an output with a single channel
    # This is the final model output. We want the pixel values in the mask to be
    # either 0 or 1. Choose an activation function which can give values in that
    # range.
    # YOUR CODE HERE
    outputs = Conv2D(1,(1,1),activation="sigmoid")(c9)

    model = Model(inputs=[input_img], outputs=[outputs])

    return model

# %%
model_name = "unet"
model = get_unet_model()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
batch_size = 8
num_epochs = 50
# Compile the model
model.compile(loss=dice_coef_loss, optimizer=Adam(lr=0.0055), metrics=[dice_coef])

# %%
# Create generator objects for training and validation
num_training_samples = len(X_train)
num_validation_samples = len(X_val)
# YOUR CODE HERE
training_batch_generator = Surface_Generator(X_train, y_train, batch_size)
validation_batch_generator = Surface_Generator(X_val, y_val, batch_size)

# %%
# OPTIONAL
# callbacks for saving models and early stopping
checkpointer = ModelCheckpoint(model_name + "/weights.{epoch:02d}-{val_loss:.2f}.hdf5", monitor=dice_coef, verbose=1,
                               save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='auto')

# %%
# Fit model
# This will take ~1.5-2 minutes per epoch on a GPU
stmillis = int(round(time.time() * 1000))
history = model.fit_generator(generator=training_batch_generator,
                    steps_per_epoch=(num_training_samples // batch_size),
                    epochs=num_epochs,
                    verbose=1,
                    validation_data=validation_batch_generator,
                    validation_steps=(num_validation_samples // batch_size),
                    use_multiprocessing=True,
                    workers=5,
                    max_queue_size=1,
                    callbacks=[checkpointer, early_stopping])
endmillis = int(round(time.time() * 1000))
print("Time taken: ", endmillis - stmillis)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/50
# 92/92 [==============================] - 49s 528ms/step - loss: 0.8812 - dice_coef: 0.1188 - val_loss: 0.9752 - val_dice_coef: 0.0197
# Epoch 2/50
# 92/92 [==============================] - 44s 473ms/step - loss: 0.7315 - dice_coef: 0.2684 - val_loss: 0.9992 - val_dice_coef: 6.6089e-04
# Epoch 3/50
# 92/92 [==============================] - 43s 465ms/step - loss: 0.7151 - dice_coef: 0.2849 - val_loss: 0.9999 - val_dice_coef: 8.8467e-04
# Epoch 4/50
# 92/92 [==============================] - 43s 467ms/step - loss: 0.6814 - dice_coef: 0.3186 - val_loss: 0.9997 - val_dice_coef: 5.2608e-04
# Epoch 5/50
# 92/92 [==============================] - 43s 466ms/step - loss: 0.6981 - dice_coef: 0.3019 - val_loss: 0.9999 - val_dice_coef: 0.0012
# Epoch 6/50
# 92/92 [==============================] - 44s 473ms/step - loss: 0.6489 - dice_coef: 0.3511 - val_loss: 0.9999 - val_dice_coef: 6.9038e-04
# Epoch 7/50
# 92/92 [==============================] - 43s 468ms/step - loss: 0.6604 - dice_coef: 0.3396 - val_loss: 0.9999 - val_dice_coef: 0.0021
# Epoch 8/50
# 92/92 [==============================] - 43s 466ms/step - loss: 0.6296 - dice_coef: 0.3704 - val_loss: 0.7081 - val_dice_coef: 0.1821
# Epoch 9/50
# 92/92 [==============================] - 42s 459ms/step - loss: 0.6321 - dice_coef: 0.3679 - val_loss: 0.6861 - val_dice_coef: 0.2224
# Epoch 10/50
# 92/92 [==============================] - 43s 472ms/step - loss: 0.6348 - dice_coef: 0.3652 - val_loss: 0.9893 - val_dice_coef: 0.0053
# Epoch 11/50
# 92/92 [==============================] - 43s 470ms/step - loss: 0.6412 - dice_coef: 0.3588 - val_loss: 0.9926 - val_dice_coef: 0.0072
# Epoch 12/50
# 92/92 [==============================] - 43s 464ms/step - loss: 0.6164 - dice_coef: 0.3836 - val_loss: 0.9430 - val_dice_coef: 0.0129
# Epoch 13/50
# 92/92 [==============================] - 43s 470ms/step - loss: 0.6151 - dice_coef: 0.3849 - val_loss: 0.5400 - val_dice_coef: 0.3319
# Epoch 14/50
# 92/92 [==============================] - 43s 464ms/step - loss: 0.6132 - dice_coef: 0.3867 - val_loss: 1.0000 - val_dice_coef: 0.0318
# Epoch 15/50
# 92/92 [==============================] - 44s 481ms/step - loss: 0.5775 - dice_coef: 0.4225 - val_loss: 0.9106 - val_dice_coef: 0.0888
# Epoch 16/50
# 92/92 [==============================] - 43s 470ms/step - loss: 0.6222 - dice_coef: 0.3778 - val_loss: 0.9873 - val_dice_coef: 0.0103
# Epoch 17/50
# 92/92 [==============================] - 43s 466ms/step - loss: 0.5878 - dice_coef: 0.4122 - val_loss: 0.4794 - val_dice_coef: 0.3328
# Epoch 18/50
# 92/92 [==============================] - 42s 461ms/step - loss: 0.5954 - dice_coef: 0.4046 - val_loss: 1.0000 - val_dice_coef: 0.0184
# Epoch 19/50
# 92/92 [==============================] - 43s 470ms/step - loss: 0.6131 - dice_coef: 0.3869 - val_loss: 0.9641 - val_dice_coef: 0.0526
# Epoch 20/50
# 92/92 [==============================] - 43s 472ms/step - loss: 0.6015 - dice_coef: 0.3985 - val_loss: 0.2368 - val_dice_coef: 0.4273
# Epoch 21/50
# 92/92 [==============================] - 42s 458ms/step - loss: 0.5615 - dice_coef: 0.4385 - val_loss: 0.5128 - val_dice_coef: 0.3020
# Epoch 22/50
# 92/92 [==============================] - 43s 470ms/step - loss: 0.5603 - dice_coef: 0.4396 - val_loss: 0.9999 - val_dice_coef: 0.0374
# Epoch 23/50
# 92/92 [==============================] - 44s 480ms/step - loss: 0.5965 - dice_coef: 0.4035 - val_loss: 0.9999 - val_dice_coef: 0.0277
# Epoch 24/50
# 92/92 [==============================] - 42s 457ms/step - loss: 0.5268 - dice_coef: 0.4732 - val_loss: 0.9999 - val_dice_coef: 0.0797
# Epoch 25/50
# 92/92 [==============================] - 43s 466ms/step - loss: 0.5514 - dice_coef: 0.4486 - val_loss: 0.9766 - val_dice_coef: 0.0713
# Epoch 26/50
# 92/92 [==============================] - 43s 467ms/step - loss: 0.5682 - dice_coef: 0.4318 - val_loss: 0.9478 - val_dice_coef: 0.0502
# Epoch 27/50
# 92/92 [==============================] - 43s 468ms/step - loss: 0.5517 - dice_coef: 0.4483 - val_loss: 0.8772 - val_dice_coef: 0.2682
# Epoch 28/50
# 92/92 [==============================] - 43s 470ms/step - loss: 0.5803 - dice_coef: 0.4197 - val_loss: 0.8614 - val_dice_coef: 0.1072
# Epoch 29/50
# 92/92 [==============================] - 42s 456ms/step - loss: 0.5374 - dice_coef: 0.4626 - val_loss: 0.9941 - val_dice_coef: 0.0084
# Epoch 30/50
# 92/92 [==============================] - 43s 465ms/step - loss: 0.5629 - dice_coef: 0.4371 - val_loss: 1.0000 - val_dice_coef: 0.1204
# Epoch 00030: early stopping
# Time taken:  1298248

# %%
# Save the trained weights
model.save(model_name + ".h5")

# Save model config as json
model_json = model.to_json()
with open(model_name + ".json", "w") as json_file:
    json_file.write(model_json)

# Persist the model to your google drive [VERY IMPORTANT]
# !cp unet.* gdrive/My\ Drive/Colab\ Notebooks/

# %%
# Confirm if model did get saved
# !ls -ltr gdrive/My\ Drive/Colab\ Notebooks/unet*
# Out:
# -rw------- 1 root root  11883 Apr 17 00:36 'gdrive/My Drive/Colab Notebooks/unet.json'
# -rw------- 1 root root 455184 Apr 17 00:36 'gdrive/My Drive/Colab Notebooks/unet.h5'

# %%
# In case you wish to load your saved model
# !cp gdrive/My\ Drive/Colab\ Notebooks/unet* .

model.load_weights("unet.h5")

# %%
import gc
gc.collect()

# Load test data in X_test and y_test
# YOUR CODE HERE
X_test, y_test = load_data("Test")
X_test = np.array(X_test)
y_test = np.array(y_test)
print (X_test.shape, y_test.shape)
# Out:
# (454,) (454,)

# %% [markdown]
# Output shape should be (454,) (454,)

# %% [markdown]
# [OPTIONAL] Shuffle and select 25 elements for quick testing

# %%
np.random.seed = 629
p = np.random.permutation(len(X_test))
X_test = X_test[p]
y_test = y_test[p]

# X_test = X_test[:25]
# y_test = y_test[:25]

# %%
# Predict using model.predict_generator().
# YOUR CODE HERE
test_data_generator = Surface_Generator(X_test, y_test, batch_size, test=True)
y_pred = model.predict_generator(test_data_generator)

# %%
# y_true will have the true masks
y_true = test_data_generator.get_all_masks()
print ("Dice coefficient on test data: ", K.get_value(dice_coef(y_true, y_pred)))
# Out:
# Dice coefficient on test data:  0.1430741

# %% [markdown]
# The dice coefficient on test data should be close to 0.7

# %% [markdown]
# Visulaizing the mask for a random image

# %%
# Convert sigmoid outputs to binary class labels
y_pred[20][y_pred[20] >= 0.5] = 1
y_pred[20][y_pred[20] < 0.5] = 0

# %%
import matplotlib.pyplot as plt
plt.imshow(y_true[20][:,:,0], cmap='gray')
plt.show()

# %%
plt.imshow(y_pred[20][:,:,0], cmap='gray')
plt.show()

# %%
# Dice coefficient on this example
K.get_value(dice_coef(y_true[20], y_pred[20]))
# Out:
# 0.49493375

# %% [markdown]
# Data augmentation techniques almost always help in improving the performance of deep learning models.
#
#
# Try beating the result obtained above by doing some kind of data augmentation and leave the code/results in the jupyter file.
#
# Provide the dice coefficient obtained on the new model trained with data augmentation.
#
# ---
#
# # Experimentation Zone
# You may write any custom code here. The data augmentation part will be evaluated from this region.
